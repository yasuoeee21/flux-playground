# %%
import os
from llm.api import ContentBuilder, Agent
import json
from PIL import Image
import random
from utils import down_size

# %%
qa_dir = '/amax/hchuz/architectural_heritage/data/testing_qa'
img_dir = '/amax/hchuz/architectural_heritage/data/testing'

# %%
name = os.listdir(qa_dir)[0][:-5]
with open(os.path.join(qa_dir, name+'.json'), 'r') as f:
    qa = json.load(f)
img = Image.open(os.path.join(img_dir, name+'.png'))
if img.height * img.width > 2000:
    img = down_size(img)

# %%
qa['questions'][0]
# Out:
# {'question': 'Is there a horizontal element dividing the second and third floors?',
#  'question_type': 'element_distribution',
#  'question_format': 'descriptive',
#  'options': {'reference': ['Yes, a [string course/cornice/decoration band/balustrade] is present between the second and third floors, creating a clear horizontal division',
#    'A subtle horizontal division exists but without prominent decorative elements',
#    'No significant horizontal division is present between these floors']},
#  'answer': 'Yes, there is a prominent horizontal cornice between the second and third floors. Additionally, the arch-like structure beneath the cornice further emphasizes this division.'}

# %%
api_key = 'sk-b03ea54c4a9e4adb8f6a4776d5d17d10'
model = "qwen-vl-max"
agent = Agent(token=api_key, model=model)

# %%
contentbuilder = ContentBuilder()
contentbuilder.add_text('hi')
text = agent.chat(contentbuilder.finish())
agent.clear()
print(text)
# Out:
# ---------------------------------------------------------------------------
# SDKError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 contentbuilder = ContentBuilder()
#       2 contentbuilder.add_text('hi')
# ----> 3 text = agent.chat(contentbuilder.finish())
#       4 agent.clear()
#       5 print(text)
#
# File /amax/hchuz/architectural_heritage/llm/api.py:59, in Agent.chat(self, content, temperature)
#      56 def chat(self, content, temperature=0.2):
#      57     self.conversation.append({"role": "user", "content": content})
# ---> 59     response = self.client.chat.complete(
#      60         model=self.model,
#      61         messages=self.conversation,
#      62         temperature=temperature
#      63     )
#      64     #print(response)
#      66     assistant_data = response.choices[0].message
#
# ...
